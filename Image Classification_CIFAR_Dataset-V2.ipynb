# %%
from tensorflow.keras import datasets, models, layers, optimizers
from tensorflow.keras.layers import Dropout, Flatten, Dense
import matplotlib.pyplot as plt

# %%
#load data
(X_train,y_train),(X_test,y_test)=datasets.cifar10.load_data()

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
y_test.shape
# Out:
# (10000, 1)

# %%
plt.figure(figsize= (12,12))
for i in range(6*6):
    plt.subplot(6,6,i+1)
    plt.axis('off')
    plt.imshow(X_train[i])

# %%
X_train.shape[1:]
# Out:
# (32, 32, 3)

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, num_classes=10)

model = models.Sequential() 
model.add(Flatten(input_shape=(32,32,3))) 
model.add(Dense(100, activation=layers.LeakyReLU(alpha=0.3))) 
model.add(Dropout(0.5)) 
model.add(Dense(50, activation=layers.LeakyReLU(alpha=0.3))) 
model.add(Dropout(0.3)) 
model.add(Dense(32, activation=layers.LeakyReLU(alpha=0.3))) 
model.add(Dropout(0.3)) 
model.add(Dense(10, activation='softmax'))

model.compile(loss='binary_crossentropy',
   optimizer=optimizers.RMSprop(lr=1e-4),
   metrics=['acc'])

history = model.fit(X_train, y_train, 
   epochs=2)
# Out:
# Epoch 1/2
# 1563/1563 [==============================] - 33s 19ms/step - loss: 5.2530 - acc: 0.1166
# Epoch 2/2
# 1563/1563 [==============================] - 29s 19ms/step - loss: 1.6179 - acc: 0.1238
